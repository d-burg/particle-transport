# %%
import astropy.units as u
import numpy as np
from astropy.io import ascii

import naima
from naima.models import (
    BrokenPowerLaw,
    EblAbsorptionModel,
    ExponentialCutoffPowerLaw,
    ExponentialCutoffBrokenPowerLaw,
    InverseCompton,
    Synchrotron,
)

## Read data

soft_xray1 = ascii.read("mos1+mos2_pwn_nh-corr.dat")
#soft_xray2 = ascii.read("chandra_pwn_nh-corr.dat")
vhe = ascii.read("HAWC_J1826-128.dat")

## Model definition

def ElectronSynIC(pars, data):

    # Match parameters to ECPL properties, and give them the appropriate units
    amplitude = 10 ** pars[0] / u.eV
    e_break = (10 ** pars[1]) * u.TeV
    alpha1 = pars[2]
    alpha2 = pars[3]
    e_cutoff = (10 ** pars[4]) * u.TeV
    B = pars[5] * u.uG

    # Initialize instances of the particle distribution and radiative models
    ECBPL = ExponentialCutoffBrokenPowerLaw(amplitude, 1.0 * u.TeV, e_break, alpha1, alpha2, e_cutoff, beta=1.0)
    # Compute IC on CMB and on a FIR component with values from GALPROP for the
    # position of RXJ1713
    IC = InverseCompton(
        ECBPL,
        seed_photon_fields=[
            "CMB",
            ["FIR", 9.5 * u.K, 10.0 * u.eV / u.cm ** 3],
        ],
        Eemin=1 * u.GeV,
    )
    SYN = Synchrotron(ECBPL, B=B)

    # compute flux at the energies given in data['energy']
    model = IC.flux(data, distance=3.5 * u.kpc) + SYN.flux(
        data, distance=3.5 * u.kpc
    )

    # The first array returned will be compared to the observed spectrum for
    # fitting. All subsequent objects will be stored in the sampler metadata
    # blobs.
    return model, IC.compute_We(Eemin=1 * u.TeV)


## Prior definition


def lnprior(pars):
    """
    Return probability of parameter values according to prior knowledge.
    Parameter limits should be done here through uniform prior ditributions
    """
    # Limit norm and B to be positive
    logprob = (
        naima.uniform_prior(pars[0], 0.0, np.inf)
        + naima.uniform_prior(pars[1], -1, 5)
        + naima.uniform_prior(pars[3], 0, np.inf)
    )

    return logprob


if __name__ == "__main__":

    ## Set initial parameters and labels
    # Estimate initial magnetic field and get value in uG
    B0 = 2 * naima.estimate_B(soft_xray1, vhe).to("uG").value
    #B0 = 5

    p0 = np.array((33, 1, 1.7, 2.8, np.log10(48.0), B0))
    labels = ["log10(norm)", "e_break", "alpha1", "alpha2", "log10(cutoff)", "B"]

    ## Run sampler
    sampler, pos = naima.run_sampler(
        data_table=[soft_xray1, vhe],
        p0=p0,
        labels=labels,
        model=ElectronSynIC,
        prior=lnprior,
        nwalkers=32,
        nburn=100,
        nrun=20,
        threads=4,
        prefit=True,
        interactive=False,
    )

#    imf = naima.InteractiveModelFitter(
#        ElectronSynIC,
#        p0,
#        labels=labels,
#        e_range=[1e-09 * u.GeV, 1e05 * u.GeV],
#    )

    ## Save run results to HDF5 file (can be read later with naima.read_run)
    naima.save_run("J1826_HAWC_SynIC", sampler)
    
    ## Diagnostic plots
    naima.save_diagnostic_plots(
        "J1826_HAWC_ECBPL",
        sampler,
        sed=True,
        blob_labels=["Spectrum", "$W_e$($E_e>1$ TeV)"],
    )
    naima.save_results_table("J1826_HAWC_ECBPL", sampler)
    
    plt = naima.plot_fit(sampler, label="Eel Pulsar Wind Nebula SED", sed=True, confs=[3,1], e_range=[0.00001*u.eV, 100*u.TeV])
    
    plt.savefig('J1826_SED_ECBPL.pdf', format='pdf', bbox_inches='tight')
    
    plt.show()
# Out:
# WARNING: "cl" keyword not provided in input data table, upper limits will be assumed to be at 90% confidence level [naima.utils]
# WARNING: "cl" keyword not provided in input data table, upper limits will be assumed to be at 90% confidence level [naima.utils]
# INFO: Finding Maximum Likelihood parameters through Nelder-Mead fitting... [naima.core]
# INFO:    Initial parameters: [35.77545396  1.          1.7         2.8         1.68124124  1.33046388] [naima.core]
# INFO:    Initial lnprob(p0): -1345424.572 [naima.core]
# INFO:    New ML parameters : [32.37669356  0.48875075  1.5187479   1.87316026  2.97375897  2.18302464] [naima.core]
# INFO:    Maximum lnprob(p0): -14.951 [naima.core]
# Burning in the 32 walkers with 100 steps...
#
# Progress of the run: 0 percent (0 of 100 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.4            0.488           1.52            1.87            2.97            2.18
#   Last ensemble std    :      0.107          0.0038          0.00647         0.0117           0.015          0.0166
#   Last ensemble lnprob :  avg: -28.163, max: -14.781
#
# Progress of the run: 5 percent (5 of 100 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.4            0.49            1.52            1.87            2.97            2.19
#   Last ensemble std    :     0.0799          0.0124          0.0107          0.0263          0.0289          0.0408
#   Last ensemble lnprob :  avg: -22.363, max: -14.661
#
# Progress of the run: 10 percent (10 of 100 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.4            0.49            1.52            1.87            2.97            2.19
#   Last ensemble std    :     0.0916           0.021          0.0183          0.0345          0.0394          0.0623
#   Last ensemble lnprob :  avg: -18.555, max: -14.548
#
# Progress of the run: 15 percent (15 of 100 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.4            0.492           1.52            1.87            2.97            2.18
#   Last ensemble std    :      0.14           0.0367           0.04           0.0647          0.0871          0.0995
#   Last ensemble lnprob :  avg: -18.193, max: -14.481
#
# Progress of the run: 20 percent (20 of 100 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.4            0.505           1.51            1.87            2.98            2.21
#   Last ensemble std    :      0.215          0.0608          0.0574           0.091           0.103           0.178
#   Last ensemble lnprob :  avg: -16.750, max: -14.171
#
# Progress of the run: 25 percent (25 of 100 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.3            0.515           1.51            1.86            2.97            2.25
#   Last ensemble std    :      0.287           0.135           0.146           0.136           0.306           0.266
#   Last ensemble lnprob :  avg: -16.647, max: -12.585
#
# Progress of the run: 30 percent (30 of 100 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.3            0.534           1.49            1.87            2.92            2.27
#   Last ensemble std    :      0.246           0.115           0.147           0.138           0.351           0.196
#   Last ensemble lnprob :  avg: -16.172, max: -13.298
#
# Progress of the run: 35 percent (35 of 100 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.3            0.55            1.49            1.87            2.93            2.31
#   Last ensemble std    :      0.24            0.129           0.159           0.143           0.368           0.175
#   Last ensemble lnprob :  avg: -16.010, max: -13.759
#
# Progress of the run: 40 percent (40 of 100 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.3            0.545           1.48            1.85            2.95            2.32
#   Last ensemble std    :      0.268           0.148           0.193           0.15            0.495           0.266
#   Last ensemble lnprob :  avg: -15.762, max: -11.204
#
# Progress of the run: 45 percent (45 of 100 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.4            0.527           1.52            1.87            2.94            2.33
#   Last ensemble std    :      0.424           0.19            0.26            0.25            0.599           0.316
#   Last ensemble lnprob :  avg: -15.596, max: -9.229
#
# Progress of the run: 50 percent (50 of 100 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.4            0.506           1.55            1.91              3              2.4
#   Last ensemble std    :       0.5            0.228           0.265           0.31            0.559           0.34
#   Last ensemble lnprob :  avg: -15.244, max: -9.229
#
# Progress of the run: 55 percent (55 of 100 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.5            0.501           1.62            1.97            3.04            2.51
#   Last ensemble std    :      0.554           0.248           0.321           0.34            0.734           0.338
#   Last ensemble lnprob :  avg: -14.288, max: -9.479
#
# Progress of the run: 60 percent (60 of 100 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.493           1.72              2             3.02            2.59
#   Last ensemble std    :      0.582           0.338           0.411           0.345           1.23            0.355
#   Last ensemble lnprob :  avg: -13.990, max: -9.479
#
# Progress of the run: 65 percent (65 of 100 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.6            0.513            1.7            2.01            3.01            2.65
#   Last ensemble std    :      0.598           0.275           0.446           0.349           1.03            0.316
#   Last ensemble lnprob :  avg: -13.437, max: -9.852
#
# Progress of the run: 70 percent (70 of 100 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.519           1.78            2.09            3.16            2.64
#   Last ensemble std    :      0.586           0.354           0.477           0.356           1.07            0.291
#   Last ensemble lnprob :  avg: -13.334, max: -9.625
#
# Progress of the run: 75 percent (75 of 100 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.519           1.78            2.07            3.13            2.64
#   Last ensemble std    :      0.649           0.438           0.625           0.374            1.4            0.362
#   Last ensemble lnprob :  avg: -13.269, max: -9.525
#
# Progress of the run: 80 percent (80 of 100 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.479           1.82            2.07            3.11            2.64
#   Last ensemble std    :      0.653           0.396           0.584           0.349           1.34            0.359
#   Last ensemble lnprob :  avg: -12.852, max: -9.488
# Progress of the run: 85 percent (85 of 100 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.482           1.84            2.07            3.16             2.7
#   Last ensemble std    :      0.656           0.49            0.587           0.359           1.33            0.365
#   Last ensemble lnprob :  avg: -12.619, max: -9.511
#
# Progress of the run: 90 percent (90 of 100 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.475           1.84            2.05            3.15            2.73
#   Last ensemble std    :      0.672           0.517           0.656           0.357           1.45            0.391
#   Last ensemble lnprob :  avg: -12.669, max: -9.450
#
# Progress of the run: 95 percent (95 of 100 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.476           1.85            2.03            3.27             2.7
#   Last ensemble std    :      0.644           0.629           0.709           0.345           1.69            0.413
#   Last ensemble lnprob :  avg: -12.303, max: -9.529
#
# Walker burn in finished, running 20 steps...
#
# Progress of the run: 0 percent (0 of 20 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.466           1.88            2.03             3.1            2.75
#   Last ensemble std    :      0.617           0.599           0.687           0.335           1.65            0.405
#   Last ensemble lnprob :  avg: -12.279, max: -9.529
#
# Progress of the run: 5 percent (1 of 20 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.467           1.92            2.03            3.11            2.78
#   Last ensemble std    :      0.62            0.604           0.689           0.335           1.65            0.406
#   Last ensemble lnprob :  avg: -12.375, max: -9.529
#
# Progress of the run: 10 percent (2 of 20 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.466            1.9            2.06            3.11            2.78
#   Last ensemble std    :      0.63            0.619           0.701           0.336           1.67            0.44
#   Last ensemble lnprob :  avg: -12.538, max: -9.567
#
# Progress of the run: 15 percent (3 of 20 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.467            1.9            2.06            3.11            2.78
#   Last ensemble std    :      0.647           0.627           0.719           0.34            1.67            0.436
#   Last ensemble lnprob :  avg: -12.474, max: -9.567
#
# Progress of the run: 20 percent (4 of 20 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.466           1.94            2.06            3.17             2.8
#   Last ensemble std    :      0.647           0.626           0.688           0.352           1.66            0.434
#   Last ensemble lnprob :  avg: -12.476, max: -9.567
#
# Progress of the run: 25 percent (5 of 20 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.464           1.92            2.06            3.15             2.8
#   Last ensemble std    :      0.648           0.627           0.69            0.351           1.62            0.438
#   Last ensemble lnprob :  avg: -12.449, max: -9.567
#
# Progress of the run: 30 percent (6 of 20 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.463           1.92            2.06            3.15            2.81
#   Last ensemble std    :      0.647           0.63            0.706           0.348            1.8            0.458
#   Last ensemble lnprob :  avg: -12.578, max: -9.567
#
# Progress of the run: 35 percent (7 of 20 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.463           1.86            2.06            3.21            2.81
#   Last ensemble std    :      0.635           0.627           0.725           0.337           1.52            0.437
#   Last ensemble lnprob :  avg: -12.563, max: -9.567
#
# Progress of the run: 40 percent (8 of 20 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.463           1.87            2.06             3.2            2.81
#   Last ensemble std    :      0.626           0.631           0.726           0.335           1.53            0.451
#   Last ensemble lnprob :  avg: -12.529, max: -9.567
#
# Progress of the run: 45 percent (9 of 20 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.463           1.87            2.06             3.2            2.84
#   Last ensemble std    :      0.651           0.65            0.727           0.342           1.51            0.449
#   Last ensemble lnprob :  avg: -12.516, max: -9.567
#
# Progress of the run: 50 percent (10 of 20 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.461            1.9            2.06            3.19            2.84
#   Last ensemble std    :      0.687           0.657           0.827           0.356           1.53            0.541
#   Last ensemble lnprob :  avg: -12.697, max: -9.567
#
# Progress of the run: 55 percent (11 of 20 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.463            1.9            2.08            3.26             2.8
#   Last ensemble std    :      0.681           0.768           0.832           0.372           1.74            0.545
#   Last ensemble lnprob :  avg: -12.565, max: -9.233
#
# Progress of the run: 60 percent (12 of 20 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.464            1.9            2.08            3.26            2.79
#   Last ensemble std    :      0.679           0.769           0.823           0.373           1.76            0.543
#   Last ensemble lnprob :  avg: -12.528, max: -9.567
#
# Progress of the run: 65 percent (13 of 20 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.7            0.467            1.9            2.07            3.26            2.79
#   Last ensemble std    :      0.649           0.574           0.822           0.302           1.53            0.54
#   Last ensemble lnprob :  avg: -12.502, max: -9.533
#
# Progress of the run: 70 percent (14 of 20 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.9            0.467           2.01             2.1            3.24            2.79
#   Last ensemble std    :      0.653           0.583           0.826           0.302           1.52            0.525
#   Last ensemble lnprob :  avg: -12.461, max: -9.533
# Progress of the run: 75 percent (15 of 20 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.9            0.467           2.01             2.1            3.24            2.79
#   Last ensemble std    :      0.648           0.584           0.825           0.288           1.49            0.516
#   Last ensemble lnprob :  avg: -12.347, max: -9.533
#
# Progress of the run: 80 percent (16 of 20 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.9            0.467           2.01             2.1            3.24            2.79
#   Last ensemble std    :      0.667           0.589           0.844           0.293            1.5            0.544
#   Last ensemble lnprob :  avg: -12.182, max: -9.533
#
# Progress of the run: 85 percent (17 of 20 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.8            0.467           2.01             2.1            3.39            2.79
#   Last ensemble std    :      0.661           0.58            0.843           0.296           1.51            0.539
#   Last ensemble lnprob :  avg: -12.181, max: -9.533
#
# Progress of the run: 90 percent (18 of 20 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.8            0.464           2.03             2.1            3.39            2.83
#   Last ensemble std    :      0.67            0.51            0.859           0.287           1.45            0.524
#   Last ensemble lnprob :  avg: -12.136, max: -9.558
#
# Progress of the run: 95 percent (19 of 20 steps)
#                            --log10(norm)-- ----e_break---- ----alpha1----- ----alpha2----- -log10(cutoff)- -------B-------
#   Last ensemble median :      32.8            0.466           2.04            2.08            3.39            2.83
#   Last ensemble std    :      0.664           0.512           0.849           0.284           1.41            0.469
#   Last ensemble lnprob :  avg: -12.068, max: -9.558
# WARNING: Not writing file because file exists and clobber is False [naima.analysis]
# INFO: Plotting chain of parameter log10(norm)... [naima.analysis]
# INFO: -------------------log10(norm)--------------------
#           log10(norm) = $32.8^{+0.6}_{-0.9}$
#                  norm = $(6^{+17}_{-6})\times10^{32}$ [naima.plot]
# INFO: Plotting chain of parameter e_break... [naima.analysis]
# INFO: ---------------------e_break----------------------
#           e_break = $0.5 \pm 0.4$ [naima.plot]
# INFO: Plotting chain of parameter alpha1... [naima.analysis]
# INFO: ----------------------alpha1----------------------
#           alpha1 = $2.0^{+0.5}_{-0.8}$ [naima.plot]
# INFO: Plotting chain of parameter alpha2... [naima.analysis]
# INFO: ----------------------alpha2----------------------
#           alpha2 = $2.1 \pm 0.3$ [naima.plot]
# INFO: Plotting chain of parameter log10(cutoff)... [naima.analysis]
# INFO: ------------------log10(cutoff)-------------------
#           log10(cutoff) = $3.2^{+2}_{-0.9}$
#                  cutoff = $(1.6^{+200}_{-1.4})\times10^{3}$ [naima.plot]
# INFO: Plotting chain of parameter B... [naima.analysis]
# INFO: ------------------------B-------------------------
#           B = $2.8^{+0.7}_{-0.3}$ [naima.plot]
# INFO: Plotting corner plot... [naima.analysis]
# INFO: Plotting Spectrum... [naima.analysis]
# /Users/danielburgess/anaconda3/lib/python3.7/site-packages/naima/analysis.py:160: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   f.clf()
# /Users/danielburgess/anaconda3/lib/python3.7/site-packages/naima/analysis.py:160: UserWarning: Attempting to set identical left == right == 1.0 results in singular transformations; automatically expanding.
#   f.clf()
# INFO: Plotting $W_e$($E_e>1$ TeV)... [naima.analysis]
# INFO: Saving results table in J1826_HAWC_ECBPL_results.ecsv [naima.analysis]
# WARNING: AstropyDeprecationWarning: J1826_HAWC_ECBPL_results.ecsv already exists. Automatically overwriting ASCII files is deprecated. Use the argument 'overwrite=True' in the future. [astropy.io.ascii.ui]
# /Users/danielburgess/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:124: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
import astropy.units as u
import numpy as np
from astropy.io import ascii

import naima
from naima.models import (
    BrokenPowerLaw,
    EblAbsorptionModel,
    ExponentialCutoffPowerLaw,
    ExponentialCutoffBrokenPowerLaw,
    InverseCompton,
    Synchrotron,
)

## Read data

soft_xray1 = ascii.read("mos1+mos2_pwn_nh-corr.dat")
#soft_xray2 = ascii.read("chandra_pwn_nh-corr.dat")
vhe = ascii.read("HAWC_J1826-128.dat")

## Model definition

def ElectronSynIC(pars, data):

    # Match parameters to ECPL properties, and give them the appropriate units
    amplitude = 10 ** pars[0] / u.eV
    e_break = (10 ** pars[1]) * u.TeV
    alpha1 = pars[2]
    alpha2 = pars[3]
    e_cutoff = (10 ** pars[4]) * u.TeV
    B = pars[5] * u.uG

    # Initialize instances of the particle distribution and radiative models
    ECBPL = ExponentialCutoffBrokenPowerLaw(amplitude, 1.0 * u.TeV, e_break, alpha1, alpha2, e_cutoff, beta=2.0)
    # Compute IC on CMB and on a FIR component with values from GALPROP for the
    # position of RXJ1713
    IC = InverseCompton(
        ECBPL,
        seed_photon_fields=[
            "CMB",
            ["FIR", 9.5 * u.K, 0.5 * u.eV / u.cm ** 3],
        ],
        Eemin=100 * u.GeV,
    )
    SYN = Synchrotron(ECBPL, B=B)

    # compute flux at the energies given in data['energy']
    model = IC.flux(data, distance=3.5 * u.kpc) + SYN.flux(
        data, distance=3.5 * u.kpc
    )

    # The first array returned will be compared to the observed spectrum for
    # fitting. All subsequent objects will be stored in the sampler metadata
    # blobs.
    return model, IC.compute_We(Eemin=1 * u.TeV)


## Prior definition


def lnprior(pars):
    """
    Return probability of parameter values according to prior knowledge.
    Parameter limits should be done here through uniform prior ditributions
    """
    # Limit norm and B to be positive
    logprob = (
        naima.uniform_prior(pars[0], 0.0, np.inf)
        + naima.uniform_prior(pars[1], -1, 5)
        + naima.uniform_prior(pars[3], 0, np.inf)
    )

    return logprob


if __name__ == "__main__":

    ## Set initial parameters and labels
    # Estimate initial magnetic field and get value in uG
    B0 = 2 * naima.estimate_B(soft_xray1, vhe).to("uG").value
    #B0 = 5

    p0 = np.array((33, 1, 1.7, 2.8, np.log10(48.0), B0))
    labels = ["log10(norm)", "e_break", "alpha1", "alpha2", "log10(cutoff)", "B"]

    ## Run sampler
    sampler, pos = naima.run_sampler(
        data_table=[soft_xray1, vhe],
        p0=p0,
        labels=labels,
        model=ElectronSynIC,
        prior=lnprior,
        nwalkers=32,
        nburn=100,
        nrun=20,
        threads=4,
        prefit=True,
        interactive=True,
    )

#    imf = naima.InteractiveModelFitter(
#        ElectronSynIC,
#        p0,
#        labels=labels,
#        e_range=[1e-09 * u.GeV, 1e05 * u.GeV],
#    )

    ## Save run results to HDF5 file (can be read later with naima.read_run)
    naima.save_run("J1826_HAWC_SynIC", sampler)
    
    ## Diagnostic plots
    naima.save_diagnostic_plots(
        "J1826_HAWC_ECBPL",
        sampler,
        sed=True,
        blob_labels=["Spectrum", "$W_e$($E_e>1$ TeV)"],
    )
    naima.save_results_table("J1826_HAWC_ECBPL", sampler)
    
    plt = naima.plot_fit(sampler, label="Eel Pulsar Wind Nebula SED", sed=True, confs=[3,1], e_range=[0.00001*u.eV, 100*u.TeV])
    
    plt.savefig('J1826_SED_ECBPL.pdf', format='pdf', bbox_inches='tight')
    
    plt.show()
