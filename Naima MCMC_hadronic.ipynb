# %%
import astropy.units as u
import numpy as np
from astropy.io import ascii

import naima
from naima.models import ExponentialCutoffPowerLaw, InverseCompton, Synchrotron

## Read data

soft_xray1 = ascii.read("mos1+mos2_pwn_nh-corr.dat")
#soft_xray2 = ascii.read("chandra_pwn_nh-corr.dat")
vhe = ascii.read("HAWC_J1826-128.dat")

## Model definition

PionDecay_ECPL_p0 = np.array((46, 2.34, np.log10(80.0)))
PionDecay_ECPL_labels = ["log10(norm)", "index", "log10(cutoff)"]

# Prepare an energy array for saving the particle distribution
proton_energy = np.logspace(-3, 2, 50) * u.TeV


def PionDecay_ECPL(pars, data):
    amplitude = 10 ** pars[0] / u.TeV
    alpha = pars[1]
    e_cutoff = 10 ** pars[2] * u.TeV
#    B = pars[3] * u.uG
    B = 12 * u.uG

    ECPL = naima.models.ExponentialCutoffPowerLaw(
        amplitude, 30 * u.TeV, alpha, e_cutoff
    )
    PP = naima.models.PionDecay(ECPL, nh=500.0 * u.cm ** -3)
    SYN = Synchrotron(ECPL, B=B)

    model = PP.flux(data, distance=3.5 * u.kpc) + SYN.flux(data, distance=3.5 * u.kpc)
    # Save a realization of the particle distribution to the metadata blob
    proton_dist = PP.particle_distribution(proton_energy)
    # Compute the total energy in protons above 1 TeV for this realization
    Wp = PP.compute_Wp(Epmin=1 * u.TeV)

    # Return the model, proton distribution and energy in protons to be stored
    # in metadata blobs
    return model, (proton_energy, proton_dist), Wp


def PionDecay_ECPL_lnprior(pars):
    logprob = (
        naima.uniform_prior(pars[0], 0.0, np.inf)
        + naima.uniform_prior(pars[1], -1, 5)
    )
    return logprob

## Prior definition


#def lnprior(pars):
#    """
#    Return probability of parameter values according to prior knowledge.
#    Parameter limits should be done here through uniform prior ditributions
#    """
#    # Limit norm and B to be positive
#    logprob = (
#        naima.uniform_prior(pars[0], 0.0, np.inf)
#        + naima.uniform_prior(pars[1], -1, 5)
#        + naima.uniform_prior(pars[3], 0, np.inf)
#    )
#
#    return logprob


if __name__ == "__main__":

    ## Set initial parameters and labels
    # Estimate initial magnetic field and get value in uG
#    B0 = 2 * naima.estimate_B(soft_xray1, vhe).to("uG").value
    #B0 = 5

#    p0 = np.array((33, 2.5, np.log10(48.0), B0))
#    B0 = 2 * naima.estimate_B(soft_xray1, vhe).to("uG").value
    labels = ["log10(norm)", "index", "log10(cutoff)", "B"]

    ## Run sampler
    sampler, pos = naima.run_sampler(
        data_table=[soft_xray1, vhe],
        p0=PionDecay_ECPL_p0,
        labels=labels,
        model=PionDecay_ECPL,
        prior=PionDecay_ECPL_lnprior,
        nwalkers=32,
        nburn=100,
        nrun=20,
        threads=4,
        prefit=True,
        interactive=False,
    )

    ## Save run results to HDF5 file (can be read later with naima.read_run)
    naima.save_run("J1826_HAWC_PP", sampler)
    
    ## Diagnostic plots
    naima.save_diagnostic_plots(
        "J1826_HAWC_PP",
        sampler,
        sed=True,
        blob_labels=["Spectrum", "$W_e$($E_e>1$ TeV)"],
    )
    naima.save_results_table("J1826_HAWC_PP", sampler)
    
    plt = naima.plot_fit(sampler, label="Eel Pulsar Wind Nebula SED", sed=True, confs=[3,1], e_range=[0.00001*u.eV, 100*u.TeV])
    
    plt.savefig('J1826_SED_HAWC_PP.pdf', format='pdf', bbox_inches='tight')
    
    plt.show()
# Out:
# WARNING: "cl" keyword not provided in input data table, upper limits will be assumed to be at 90% confidence level [naima.utils]
# INFO: Finding Maximum Likelihood parameters through Nelder-Mead fitting... [naima.core]
# INFO:    Initial parameters: [41.36592918  2.34        1.90308999] [naima.core]
# INFO:    Initial lnprob(p0): -90.279 [naima.core]
# INFO:    New ML parameters : [40.79451229  1.72791894  2.20022721] [naima.core]
# INFO:    Maximum lnprob(p0): -32.041 [naima.core]
# Burning in the 32 walkers with 100 steps...
#
# Progress of the run: 0 percent (0 of 100 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.73             2.2
#   Last ensemble std    :      0.182          0.00757         0.0127
#   Last ensemble lnprob :  avg: -76.565, max: -32.048
#
# Progress of the run: 5 percent (5 of 100 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.73             2.2
#   Last ensemble std    :      0.128          0.0101          0.0168
#   Last ensemble lnprob :  avg: -49.111, max: -32.037
#
# Progress of the run: 10 percent (10 of 100 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.73            2.21
#   Last ensemble std    :     0.0842          0.0142           0.023
#   Last ensemble lnprob :  avg: -39.994, max: -32.051
#
# Progress of the run: 15 percent (15 of 100 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.73            2.21
#   Last ensemble std    :     0.0543          0.0177          0.0312
#   Last ensemble lnprob :  avg: -34.633, max: -32.037
#
# Progress of the run: 20 percent (20 of 100 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.73             2.2
#   Last ensemble std    :      0.053          0.0646           0.079
#   Last ensemble lnprob :  avg: -33.134, max: -32.032
#
# Progress of the run: 25 percent (25 of 100 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.74            2.19
#   Last ensemble std    :     0.0888           0.159           0.102
#   Last ensemble lnprob :  avg: -33.009, max: -32.057
#
# Progress of the run: 30 percent (30 of 100 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.75            2.19
#   Last ensemble std    :      0.134           0.233           0.144
#   Last ensemble lnprob :  avg: -33.275, max: -32.045
#
# Progress of the run: 35 percent (35 of 100 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.72            2.21
#   Last ensemble std    :      0.119           0.275           0.187
#   Last ensemble lnprob :  avg: -33.129, max: -32.046
#
# Progress of the run: 40 percent (40 of 100 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.7            1.71            2.21
#   Last ensemble std    :      0.148           0.289           0.207
#   Last ensemble lnprob :  avg: -33.306, max: -32.104
#
# Progress of the run: 45 percent (45 of 100 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.7            1.62            2.22
#   Last ensemble std    :      0.117           0.345           0.314
#   Last ensemble lnprob :  avg: -32.990, max: -32.020
#
# Progress of the run: 50 percent (50 of 100 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.7            1.62            2.24
#   Last ensemble std    :      0.147           0.466           0.334
#   Last ensemble lnprob :  avg: -33.621, max: -32.017
#
# Progress of the run: 55 percent (55 of 100 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.65            2.23
#   Last ensemble std    :      0.141           0.453           0.37
#   Last ensemble lnprob :  avg: -33.109, max: -31.989
#
# Progress of the run: 60 percent (60 of 100 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.61            2.21
#   Last ensemble std    :      0.14            0.539           0.317
#   Last ensemble lnprob :  avg: -33.148, max: -32.041
#
# Progress of the run: 65 percent (65 of 100 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.7            1.58            2.19
#   Last ensemble std    :      0.129           0.513            0.4
#   Last ensemble lnprob :  avg: -33.199, max: -32.168
#
# Progress of the run: 70 percent (70 of 100 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.7            1.65            2.27
#   Last ensemble std    :      0.154           0.564           0.354
#   Last ensemble lnprob :  avg: -33.555, max: -32.042
#
# Progress of the run: 75 percent (75 of 100 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.7            1.62            2.27
#   Last ensemble std    :      0.138           0.514           0.351
#   Last ensemble lnprob :  avg: -33.136, max: -32.073
#
# Progress of the run: 80 percent (80 of 100 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.7            1.64            2.28
#   Last ensemble std    :      0.162           0.532           0.375
#   Last ensemble lnprob :  avg: -33.107, max: -32.084
#
# Progress of the run: 85 percent (85 of 100 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.76            2.26
#   Last ensemble std    :      0.162           0.515           0.402
#   Last ensemble lnprob :  avg: -33.326, max: -32.117
#
# Progress of the run: 90 percent (90 of 100 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.71            2.25
#   Last ensemble std    :      0.167           0.571           0.401
#   Last ensemble lnprob :  avg: -33.434, max: -32.164
#
# Progress of the run: 95 percent (95 of 100 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.64            2.24
#   Last ensemble std    :      0.166           0.517           0.39
#   Last ensemble lnprob :  avg: -33.223, max: -32.097
#
# Walker burn in finished, running 20 steps...
#
# Progress of the run: 0 percent (0 of 20 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8             1.7            2.26
#   Last ensemble std    :      0.146           0.567           0.395
#   Last ensemble lnprob :  avg: -33.066, max: -32.015
#
# Progress of the run: 5 percent (1 of 20 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.65            2.26
#   Last ensemble std    :      0.136           0.529           0.391
#   Last ensemble lnprob :  avg: -33.019, max: -32.015
#
# Progress of the run: 10 percent (2 of 20 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.67            2.24
#   Last ensemble std    :      0.131           0.515           0.404
#   Last ensemble lnprob :  avg: -32.962, max: -32.008
#
# Progress of the run: 15 percent (3 of 20 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.66            2.24
#   Last ensemble std    :      0.126           0.506           0.399
#   Last ensemble lnprob :  avg: -33.004, max: -32.008
# Progress of the run: 20 percent (4 of 20 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.64            2.25
#   Last ensemble std    :      0.123           0.513           0.431
#   Last ensemble lnprob :  avg: -33.098, max: -32.008
#
# Progress of the run: 25 percent (5 of 20 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.67            2.25
#   Last ensemble std    :      0.131           0.542           0.483
#   Last ensemble lnprob :  avg: -33.168, max: -32.008
#
# Progress of the run: 30 percent (6 of 20 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.67            2.31
#   Last ensemble std    :      0.128           0.523           0.479
#   Last ensemble lnprob :  avg: -33.148, max: -32.008
#
# Progress of the run: 35 percent (7 of 20 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.66            2.29
#   Last ensemble std    :      0.124           0.519           0.469
#   Last ensemble lnprob :  avg: -33.105, max: -32.006
#
# Progress of the run: 40 percent (8 of 20 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.61             2.3
#   Last ensemble std    :      0.13            0.52            0.605
#   Last ensemble lnprob :  avg: -33.255, max: -32.006
#
# Progress of the run: 45 percent (9 of 20 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.63            2.32
#   Last ensemble std    :      0.133           0.538           0.745
#   Last ensemble lnprob :  avg: -33.223, max: -32.006
#
# Progress of the run: 50 percent (10 of 20 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.63             2.3
#   Last ensemble std    :      0.132           0.512            0.6
#   Last ensemble lnprob :  avg: -33.171, max: -32.006
#
# Progress of the run: 55 percent (11 of 20 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8             1.6             2.3
#   Last ensemble std    :      0.13            0.505           0.546
#   Last ensemble lnprob :  avg: -33.069, max: -32.088
#
# Progress of the run: 60 percent (12 of 20 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.57            2.29
#   Last ensemble std    :      0.13            0.508           0.565
#   Last ensemble lnprob :  avg: -33.223, max: -31.995
#
# Progress of the run: 65 percent (13 of 20 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.57             2.3
#   Last ensemble std    :      0.123           0.456           0.493
#   Last ensemble lnprob :  avg: -33.279, max: -32.026
#
# Progress of the run: 70 percent (14 of 20 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.73            2.33
#   Last ensemble std    :      0.12            0.465           0.489
#   Last ensemble lnprob :  avg: -33.198, max: -32.020
#
# Progress of the run: 75 percent (15 of 20 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.73            2.27
#   Last ensemble std    :      0.125           0.47            0.502
#   Last ensemble lnprob :  avg: -33.089, max: -32.020
#
# Progress of the run: 80 percent (16 of 20 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.83            2.34
#   Last ensemble std    :      0.111           0.451           0.502
#   Last ensemble lnprob :  avg: -33.022, max: -32.052
#
# Progress of the run: 85 percent (17 of 20 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.87            2.31
#   Last ensemble std    :      0.102           0.438           0.516
#   Last ensemble lnprob :  avg: -33.031, max: -32.052
#
# Progress of the run: 90 percent (18 of 20 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.83            2.31
#   Last ensemble std    :      0.105           0.449           0.533
#   Last ensemble lnprob :  avg: -32.978, max: -32.052
#
# Progress of the run: 95 percent (19 of 20 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      40.8            1.78             2.3
#   Last ensemble std    :      0.113           0.424           0.591
#   Last ensemble lnprob :  avg: -32.961, max: -32.052
# INFO: Plotting chain of parameter log10(norm)... [naima.analysis]
# INFO: -------------------log10(norm)--------------------
#           log10(norm) = $40.77 \pm 0.13$
#                  norm = $(5.9 \pm 1.7)\times10^{40}$ [naima.plot]
# WARNING: Not writing file because file exists and clobber is False [naima.analysis]
# INFO: Plotting chain of parameter index... [naima.analysis]
# INFO: ----------------------index-----------------------
#           index = $1.7^{+0.6}_{-0.4}$ [naima.plot]
# INFO: Plotting chain of parameter log10(cutoff)... [naima.analysis]
# INFO: ------------------log10(cutoff)-------------------
#           log10(cutoff) = $2.3^{+0.6}_{-0.3}$
#                  cutoff = $200^{+700}_{-100}$ [naima.plot]
# INFO: Plotting corner plot... [naima.analysis]
# INFO: Plotting Spectrum... [naima.analysis]
# /Users/danielburgess/anaconda3/lib/python3.7/site-packages/naima/analysis.py:160: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   f.clf()
# /Users/danielburgess/anaconda3/lib/python3.7/site-packages/naima/analysis.py:160: UserWarning: Attempting to set identical left == right == 1.0 results in singular transformations; automatically expanding.
#   f.clf()
# INFO: Plotting $W_e$($E_e>1$ TeV)... [naima.analysis]
# INFO: Plotting Model output 2... [naima.analysis]
# INFO: Saving results table in J1826_HAWC_PP_results.ecsv [naima.analysis]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-b266a6691516> in <module>
#     106         blob_labels=["Spectrum", "$W_e$($E_e>1$ TeV)"],
#     107     )
# --> 108     naima.save_results_table("J1826_HAWC_PP", sampler)
#     109
#     110     plt = naima.plot_fit(sampler, label="Eel Pulsar Wind Nebula SED", sed=True, confs=[3,1], e_range=[0.00001*u.eV, 100*u.TeV])
#
# ~/anaconda3/lib/python3.7/site-packages/naima/analysis.py in save_results_table(outname, sampler, format, convert_log, last_step, include_blobs)
#     291
#     292     for p, label in enumerate(labels):
# --> 293         dist = dists[:, p]
#     294         xquant = np.percentile(dist, quant)
#     295         quantiles = dict(zip(quant, xquant))
#
# IndexError: index 3 is out of bounds for axis 1 with size 3

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1eb00ff78cf2> in <module>
# ----> 1 plt.show()
#
# NameError: name 'plt' is not defined
